# %% [markdown]
# EDA = ExpolatoryDataAnalysis
# data se meaning extract krana

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,20,5)
y=np.sin(x)
plt.plot(x,y,'-o')

# %%
plt.scatter(x,y)        #shift+tab = to show property/attributes of function

# %%
data=np.random.randn(1000)       #(sizeOfArray) .random =randomValues ,.randn= for guassian normal distributed plane 
plt.hist(data,bins=100,histtype="bar")
plt.show()

# %%
x=np.linspace(1,10,100)
plt.plot(x,np.sin(x),"o",label="sine")
plt.plot(x,np.cos(x),label="cosine")
#plt.plot(x,np.tan(x),label="tangent")
plt.legend(fancybox=True,shadow=True,borderpad=0.5,fontsize="large",labelcolor=["red","green"])

# %%
data=pd.read_csv("netflixData.csv")

# %%
data.head()
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4  7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
#
# ...

# %%
data.isnull().sum()
# Out:
# Show Id                  0
# Title                    0
# Description              0
# Director              2064
# Genres                   0
# Cast                   530
# Production Country     559
# Release Date             3
# Rating                   4
# Duration                 3
# Imdb Score             608
# Content Type             0
# Date Added            1335
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())      #null values me hitebar show krega
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x="Content Type",data=data)    #x=colname or data usko data ka btarha k ks dataset se col uthana h
# Out:
# <AxesSubplot:xlabel='Content Type', ylabel='count'>

# %% [markdown]
# Assignmnt
# hr production country me ktni movies bni h unko show krna in desc order
# format =  country name  movies_count

# %%
sns.countplot(x="Production Country",data=data)

# %%
data.loc[:,["Content Type"]].value_counts()

# %%
data.groupby("Production Country")["Content Type"].value_counts()
# Out:
# Production Country                                   Content Type
# Argentina                                            Movie           26
#                                                      TV Show         14
# Argentina, Brazil, France, Poland, Germany, Denmark  Movie            1
# Argentina, Chile                                     Movie            1
# Argentina, France                                    Movie            1
#                                                                      ..
# Uruguay, Guatemala                                   Movie            1
# Uruguay, Spain, Mexico                               Movie            1
# Vietnam                                              Movie            4
# West Germany                                         Movie            1
# Zimbabwe                                             Movie            1
# Name: Content Type, Length: 590, dtype: int64

# %%
data.replace(to_replace=np.nan,value= "none" ,inplace=True)
data2=data["Production Country"].unique()
data2["No Of Tv Show"]=data.loc[(data["Content Type"]=="Movie"),["Production Country"]].value_counts()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-4deba9308ce1> in <module>
#       1 data.replace(to_replace=np.nan,value= "none" ,inplace=True)
#       2 data2=data["Production Country"].unique()
# ----> 3 data2["No Of Tv Show"]=data.loc[(data["Content Type"]=="Movie"),["Production Country"]].value_counts()
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
def cal_noOfTvShows(d):
    if d["Content Type"]=='Tv Show':
        return c+=1
c=0     
data["No_of_TvShows"]=groupby("Content Type")["Production Country"].apply(cal_noOfTvShows)

# %%
data.isnull().sum()

# %%
print(arr)
print(len(arr))

# %%
len(arr)

# %%
ar=data["Production Country"].nunique(dropna=True)

# %%
z=data["Production Country"].unique()
print(z)
len(z)

# %%
len(data)

# %%
cn=data["Production Country"].value_counts()
