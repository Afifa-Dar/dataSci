# %%
import pandas as pd

# %%
data=pd.read_csv("sonar.all-data.csv")

# %%
data.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#    0.0090  0.0032  R
# 0  0.0052  0.0044  R
# 1  0.0095  0.0078  R
# 2  0.0040  0.0117  R
# ...

# %%
data.shape
# Out:
# (207, 61)

# %%
data.dtypes
# Out:
# 0.0200    float64
# 0.0371    float64
# 0.0428    float64
# 0.0207    float64
# 0.0954    float64
# 0.0986    float64
# 0.1539    float64
# 0.1601    float64
# 0.3109    float64
# 0.2111    float64
# 0.1609    float64
# 0.1582    float64
# 0.2238    float64
# 0.0645    float64
# 0.0660    float64
# 0.2273    float64
# 0.3100    float64
# 0.2999    float64
# 0.5078    float64
# 0.4797    float64
# 0.5783    float64
# 0.5071    float64
# 0.4328    float64
# 0.5550    float64
# 0.6711    float64
# 0.6415    float64
# 0.7104    float64
# 0.8080    float64
# 0.6791    float64
# 0.3857    float64
# 0.1307    float64
# 0.2604    float64
# 0.5121    float64
# 0.7547    float64
# 0.8537    float64
# 0.8507    float64
# 0.6692    float64
# 0.6097    float64
# 0.4943    float64
# 0.2744    float64
# 0.0510    float64
# 0.2834    float64
# 0.2825    float64
# 0.4256    float64
# 0.2641    float64
# 0.1386    float64
# 0.1051    float64
# 0.1343    float64
# 0.0383    float64
# 0.0324    float64
# ...

# %%
data.dtypes.value_counts()
# Out:
# float64    60
# object      1
# dtype: int64

# %%
pd.set_option("display.max_rows",200)
data.dtypes
# Out:
# 0.0200    float64
# 0.0371    float64
# 0.0428    float64
# 0.0207    float64
# 0.0954    float64
# 0.0986    float64
# 0.1539    float64
# 0.1601    float64
# 0.3109    float64
# 0.2111    float64
# 0.1609    float64
# 0.1582    float64
# 0.2238    float64
# 0.0645    float64
# 0.0660    float64
# 0.2273    float64
# 0.3100    float64
# 0.2999    float64
# 0.5078    float64
# 0.4797    float64
# 0.5783    float64
# 0.5071    float64
# 0.4328    float64
# 0.5550    float64
# 0.6711    float64
# 0.6415    float64
# 0.7104    float64
# 0.8080    float64
# 0.6791    float64
# 0.3857    float64
# 0.1307    float64
# 0.2604    float64
# 0.5121    float64
# 0.7547    float64
# 0.8537    float64
# 0.8507    float64
# 0.6692    float64
# 0.6097    float64
# 0.4943    float64
# 0.2744    float64
# 0.0510    float64
# 0.2834    float64
# 0.2825    float64
# 0.4256    float64
# 0.2641    float64
# 0.1386    float64
# 0.1051    float64
# 0.1343    float64
# 0.0383    float64
# 0.0324    float64
# ...

# %%
data.groupby('R')

# %%
data.groupby('R').size()
# Out:
# R
# M    111
# R     96
# dtype: int64

# %% [markdown]
# # Machine Learning

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt

# %% [markdown]
# # split data

# %%
x=data[:0:-2]   #not work well
x
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 200  0.0335  0.0258  0.0398  0.0570  0.0529  0.1091  0.1709  0.1684  0.1865
# 198  0.0116  0.0744  0.0367  0.0225  0.0076  0.0545  0.1110  0.1069  0.1708
# 196  0.0366  0.0421  0.0504  0.0250  0.0596  0.0252  0.0958  0.0991  0.1419
# 194  0.0129  0.0141  0.0309  0.0375  0.0767  0.0787  0.0662  0.1108  0.1777
# 192  0.0203  0.0121  0.0380  0.0128  0.0537  0.0874  0.1021  0.0852  0.1136
# 190  0.0315  0.0252  0.0167  0.0479  0.0902  0.1057  0.1024  0.1209  0.1241
# 188  0.0158  0.0239  0.0150  0.0494  0.0988  0.1425  0.1463  0.1219  0.1697
# 186  0.0368  0.0279  0.0103  0.0566  0.0759  0.0679  0.0970  0.1473  0.2164
# ...

# %% [markdown]
# #array based split

# %%
arr=data.values

# %%
x=arr[:,0:-1]   
y=arr[:,-1]

# %%
y
# Out:
# array(['R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
# ...

# %% [markdown]
# #series based split

# %%
x=data.drop('R',axis=1)
y=data["R"]

# %%
x
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
y
# Out:
# 0      R
# 1      R
# 2      R
# 3      R
# 4      R
#       ..
# 202    M
# 203    M
# 204    M
# 205    M
# 206    M
# Name: R, Length: 207, dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
DT=DecisionTreeClassifier()
DT.fit(x_train,y_train)
y_pred=DT.predict(x_test)
acc=accuracy_score(y_test,y_pred)*100
print(acc)
# Out:
# 69.04761904761905

# %%
#we have to apply diff models...so to improve writablity we can......
model=[]
model.append(("DT",DecisionTreeClassifier()))
model.append(("RT",RandomForestClassifier()))
model.append(("KNN",KNeighborsClassifier()))
model.append(("LR",LogisticRegression()))
model.append(("GNB",GaussianNB()))

# %%
model
# Out:
# [('DT', DecisionTreeClassifier()),
#  ('RT', RandomForestClassifier()),
#  ('KNN', KNeighborsClassifier()),
#  ('LR', LogisticRegression()),
#  ('GNB', GaussianNB())]

# %%
result=[]
name=[]
for n,m in model:
    name.append(n)
    obj=m
    obj.fit(x_train,y_train)
    y_pred=obj.predict(x_test)
    result.append(accuracy_score(y_test,y_pred)*100)

# %%
print(name,result)
# Out:
# ['DT', 'RT', 'KNN', 'LR', 'GNB'] [64.28571428571429, 92.85714285714286, 83.33333333333334, 80.95238095238095, 66.66666666666666]

# %%
plt.scatter(name,result)

# %% [markdown]
# # Deep learning
# based on ANN ,RNN work on NLP
# we have sequence models work on NLP
#
# if we have to do (bteween 2) classsifcation then do prediction on that bases(cat,dog,..) we use sigmoid
#
# we have libarary tensorflow on that we have keras.. in keras we have ANN neural networks model .....

# %%
# !pip install tensorflow

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense

# %% [raw]
# Desnse= layers
# 1st arg no of no of neurons in layer
# 2nd arg =input dimention,input dimension = no of cloumens except target
# 3rd activation function..
# activation function is sigmoid when we do classification..
# 1st layers is input
# last layer is output..
# output has only one neuron
#
# default/basic optimizer is Adam ..calclualte loss and metrices

# %%
ann_model=Sequential([
        Dense(24,input_dim=60,activation="relu"),
        Dense(12, activation='relu'),
        Dense(8, activation='relu'),
        Dense(1, activation='sigmoid')])
ann_model.compile(
    optimizer = keras.optimizers.Adam(),
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
)
ann_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 24)                1464
#
#  dense_5 (Dense)             (None, 12)                300
#
#  dense_6 (Dense)             (None, 8)                 104
#
#  dense_7 (Dense)             (None, 1)                 9
#
# ...
# Total params: 1,877
# Trainable params: 1,877
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train model
# ANN not take string

# %%
#OnneHotEnocding
data["R"].replace(to_replace=["R","M"], value=[0,1], inplace=True)

# %%
data.tail()
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
#      0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 202  0.2684  ...  0.0116  0.0098  0.0199  0.0033  0.0101  0.0065  0.0115
# 203  0.2154  ...  0.0061  0.0093  0.0135  0.0063  0.0063  0.0034  0.0032
# 204  0.2529  ...  0.0160  0.0029  0.0051  0.0062  0.0089  0.0140  0.0138
# 205  0.2354  ...  0.0086  0.0046  0.0126  0.0036  0.0035  0.0034  0.0079
# 206  0.2354  ...  0.0146  0.0129  0.0047  0.0039  0.0061  0.0040  0.0036
#
#      0.0090  0.0032  R
# 202  0.0193  0.0157  1
# ...

# %%
x=data.drop("R",axis=1)
y=data["R"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
ann_model.fit(x_train,y_train,epochs=20)          #no of times we train model..by default it is 1
# Out:
# Epoch 1/20
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6887 - accuracy: 0.4606
# Epoch 2/20
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6849 - accuracy: 0.6121
# Epoch 3/20
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6816 - accuracy: 0.6727
# Epoch 4/20
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6779 - accuracy: 0.6606
# Epoch 5/20
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6738 - accuracy: 0.6788
# Epoch 6/20
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6712 - accuracy: 0.6788
# Epoch 7/20
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6676 - accuracy: 0.6788
# Epoch 8/20
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6633 - accuracy: 0.6909
# Epoch 9/20
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6625 - accuracy: 0.7030
# Epoch 10/20
# ...

# %%
#now test accuracy ie evaluate model
#ANN evaluation diff fro ML model evaluation..
#it takes two arg ie x_test y_test and return two values ie loss , accuracy

loss,acc=ann_model.evaluate(x_test,y_test)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5973 - accuracy: 0.7619

# %%
print(loss)
print(acc)
# Out:
# 0.597253143787384
# 0.761904776096344

# %%
result.append(acc*100)
name.append("ANN")

# %%
plt.scatter(name,result)
